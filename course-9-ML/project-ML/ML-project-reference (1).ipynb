# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('DS1_C9_S7_Project_AbsenteeismAtWork_Data.csv',sep=';')
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df.to_csv('project-ml.csv')

# %%
df.columns=df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['ID', 'Reason_for_absence', 'Month_of_absence', 'Day_of_the_week',
#        'Seasons', 'Transportation_expense', 'Distance_from_Residence_to_Work',
#        'Service_time', 'Age', 'Work_load_Average/day_', 'Hit_target',
#        'Disciplinary_failure', 'Education', 'Son', 'Social_drinker',
#        'Social_smoker', 'Pet', 'Weight', 'Height', 'Body_mass_index',
#        'Absenteeism_time_in_hours'],
#       dtype='object')

# %%
df.head()
# Out:
#    ID  Reason_for_absence  Month_of_absence  Day_of_the_week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation_expense  Distance_from_Residence_to_Work  Service_time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work_load_Average/day_  ...  Disciplinary_failure  Education  Son  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason_for_absence               740 non-null    int64
#  2   Month_of_absence                 740 non-null    int64
#  3   Day_of_the_week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation_expense           740 non-null    int64
#  6   Distance_from_Residence_to_Work  740 non-null    int64
#  7   Service_time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work_load_Average/day_           740 non-null    float64
#  10  Hit_target                       740 non-null    int64
#  11  Disciplinary_failure             740 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Reason_for_absence                 0
# Month_of_absence                   0
# Day_of_the_week                    0
# Seasons                            0
# Transportation_expense             0
# Distance_from_Residence_to_Work    0
# Service_time                       0
# Age                                0
# Work_load_Average/day_             0
# Hit_target                         0
# Disciplinary_failure               0
# Education                          0
# Son                                0
# Social_drinker                     0
# Social_smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body_mass_index                    0
# Absenteeism_time_in_hours          0
# dtype: int64

# %%
df['Seasons'].unique()
# Out:
# array([1, 4, 2, 3], dtype=int64)

# %%
# 1-summer
# 2-autom
# 3-winter
# 4-spring
# pd.cut sesaon_c

# %%
df['Day_of_the_week'].unique()
# Out:
# array([3, 4, 5, 6, 2], dtype=int64)

# %%
bins=[0,1,2,3,4,5,6,7]
labels=['sun','mon','tue','wed','thurs','fri','sat']
df['Day_of_the_week_c']=pd.cut(df['Day_of_the_week'],bins=bins,labels=labels)

# %%
df
# Out:
#      ID  Reason_for_absence  Month_of_absence  Day_of_the_week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation_expense  Distance_from_Residence_to_Work  Service_time  \
# ...

# %%
df['Education'].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
# high-school
# ug
# pg
# masters
df['Disciplinary_failure'].unique()
Social_drinker
Social_smoker
# Out:
# array([0, 1], dtype=int64)

# %%
df['Reason_for_absence'].unique()
# Out:
# array([26,  0, 23,  7, 22, 19,  1, 11, 14, 21, 10, 13, 28, 18, 25, 24,  6,
#        27, 17,  8, 12,  5,  9, 15,  4,  3,  2, 16], dtype=int64)

# %%
threshold=[14,17,21]
labels=['group1','group2','group3','group4']
# functions to assign labels based on conditions
def assign_label(values):
    if values<=threshold[0]:
        return labels[0]
    elif values<=threshold[1]:
         return labels[1]
    elif values<=threshold[2]:
         return labels[2]
    else:
        return labels[3]
# apply the function to the columns and create a new columns to create a variable

# %%
df['Reason_for_absence_c']=df['Reason_for_absence'].apply(assign_label)

# %%
df['Reason_for_absence_c'].unique()
# Out:
# array(['group4', 'group1', 'group3', 'group2'], dtype=object)

# %%
df['Absenteeism_time_in_hours'].unique()
# Out:
# array([  4,   0,   2,   8,  40,   1,   7,   3,  32,   5,  16,  24,  64,
#         56,  80, 120, 112, 104,  48], dtype=int64)

# %%
df['Absenteeism_time_in_hours'].mean()
# Out:
# 6.924324324324324

# %%
df['Absenteeism_time_in_hours_c']=np.where(df['Absenteeism_time_in_hours']>df['Absenteeism_time_in_hours'].mean(),'high_absent','low_absent')

# %%
df['Absenteeism_time_in_hours_c'].unique()
# Out:
# array(['low_absent', 'high_absent'], dtype=object)

# %%
df['Hit_target'].unique()
# Out:
# array([ 97,  92,  93,  95,  99,  96,  94,  98,  81,  88, 100,  87,  91],
#       dtype=int64)

# %%
df['Hit_target'].median()
# Out:
# 95.0

# %%
df['Hit_target_c']=np.where(df['Hit_target']>df['Hit_target'].mean(),'acheived','not_acheived')

# %%
df['Hit_target_c'].unique()
# Out:
# array(['acheived', 'not_acheived'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array([33, 50, 38, 39, 28, 36, 34, 37, 41, 47, 29, 48, 32, 27, 43, 40, 31,
#        30, 49, 58, 46, 53], dtype=int64)

# %%
threshold=[30,35,40,45,50,55]
labels=['25 to 30','30 to 35','35 to 40','40 to 45','45 to 50','50 to 55','55 to 60']
def label_assign(values):
    if values<=threshold[0]:
        return labels[0]
    elif values<=threshold[1]:
        return labels[1]
    elif values<=threshold[2]:
        return labels[2]
    elif values<=threshold[3]:
        return labels[3]
    elif values<=threshold[4]:
        return labels[4]
    elif values<=threshold[5]:
        return labels[5]
    else:
        return labels[6]

# %%
df['Age_c']=df['Age'].apply(label_assign)

# %%
df['Age_c'].unique()
# Out:
# array(['30 to 35', '45 to 50', '35 to 40', '25 to 30', '40 to 45',
#        '55 to 60', '50 to 55'], dtype=object)
