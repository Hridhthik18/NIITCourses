# %%
# task1
# Display basic information about the dataset, which includes column names, number of rows and columns, and data type of the columns. 
import pandas as pd

df = pd.read_csv('DS1_C5_S3_Sales_Data_Practice.csv')
print(df.info())
print(df.shape)
print(df.dtypes)    
print(df.columns)
print(df.head())
print(df.tail())
# Also, display the count of missing values for each column.
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1574 entries, 0 to 1573
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       1574 non-null   int64
#  1   QUANTITYORDERED   1574 non-null   int64
#  2   PRICEEACH         1574 non-null   float64
#  3   SALES             1574 non-null   float64
#  4   ORDERDATE         1574 non-null   object
#  5   STATUS            1574 non-null   object
#  6   PRODUCTLINE       1574 non-null   object
#  7   MSRP              1574 non-null   int64
#  8   PRODUCTCODE       1574 non-null   object
#  9   CUSTOMERNAME      1574 non-null   object
#  10  CITY              1574 non-null   object
#  11  STATE             718 non-null    object
#  12  COUNTRY           1574 non-null   object
#  13  TERRITORY         992 non-null    object
#  14  CONTACTLASTNAME   1574 non-null   object
#  15  CONTACTFIRSTNAME  1574 non-null   object
# ...

# %%
# task2
# Separate the columns into categorical and numerical data types and display them.
print(df.select_dtypes(include=['object']).columns)
print(df.select_dtypes(include=['int64', 'float64']).columns)
# Display the summary statistics of the numerical columns.
print(df.describe())
# Display the summary statistics of categorical columns.
print(df.describe(include=['object']))
# Out:
# Index(['ORDERDATE', 'STATUS', 'PRODUCTLINE', 'PRODUCTCODE', 'CUSTOMERNAME',
#        'CITY', 'STATE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME',
#        'CONTACTFIRSTNAME', 'DEALSIZE'],
#       dtype='object')
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'SALES', 'MSRP'], dtype='object')
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH         SALES         MSRP
# count   1574.000000      1574.000000  1574.000000   1574.000000  1574.000000
# mean   10257.252859        34.981576    83.792668   3699.343393   106.995553
# std       91.800668         9.935919    21.390441   2003.345688    45.337282
# min    10100.000000         6.000000    26.880000    541.140000    33.000000
# 25%    10180.000000        27.000000    69.477500   2174.475000    71.000000
# 50%    10259.000000        34.000000   100.000000   3372.580000   102.000000
# 75%    10332.000000        43.000000   100.000000   4812.375000   141.000000
# ...

# %%
# Conduct descriptive analysis of numerical columns 'PRICE EACH', 'SALES', and 'MSRP' to determine the unique values present in each column, their respective modes, and other relevant statistics.
print(df['PRICEEACH'].unique())
print(df['PRICEEACH'].mode())
print(df['PRICEEACH'].value_counts())
print(df['PRICEEACH'].describe())
print(df['SALES'].unique())
print(df['SALES'].mode())
print(df['SALES'].value_counts())
print(df['SALES'].describe())
print(df['MSRP'].unique())
print(df['MSRP'].mode())
print(df['MSRP'].value_counts())
print(df['MSRP'].describe())
# Out:
# [100.    64.93  48.05  75.47  54.68  61.99  65.63  46.9   71.47  79.65
#   85.39  76.    99.04  64.    57.22  52.36  69.12  54.33  55.34  99.82
#   83.63  95.93  96.73  72.38  63.38  62.09  95.35  89.38  63.84  75.01
#   73.42  81.4   64.64  82.99  92.57  77.41  74.21  90.17  76.61  83.79
#   69.43  93.56  81.62  67.83  70.26  97.89  93.28  64.74  75.2   88.45
#   97.6   87.06  93.77  99.66  91.44  87.33  95.55  86.3   95.13  36.11
#   50.18  93.16  50.14  49.06  54.99  43.13  58.22  51.21  44.21  54.45
#   53.37  63.61  48.52  51.75  57.68  56.07  89.89  58.95  72.41  98.63
#   52.83  99.55  56.3   42.64  74.04  82.39  79.31  88.55  63.14  73.92
#   90.86  85.47  66.99  64.68  83.93  74.69  92.4   91.63  78.54  65.45
#   67.76  79.22  32.47  64.69  43.05  88.    67.8   50.25  53.88  62.36
#   69.62  57.51  61.15  59.33  71.44  62.96  50.85  72.65  61.75  49.04
#   84.25  56.91  49.3   63.57  98.99  52.67  94.79  47.18  78.11  64.9
# ...

# %%
# Perform descriptive analysis of categorical columns 'PRODUCTLINE', 'CUSTOMERNAME', and 'COUNTRY' to identify the unique values present in each column, their respective modes, and other relevant statistics.
print(df['PRODUCTLINE'].unique())
print(df['PRODUCTLINE'].mode())
print(df['PRODUCTLINE'].value_counts())
print(df['PRODUCTLINE'].describe())
print(df['CUSTOMERNAME'].unique())
print(df['CUSTOMERNAME'].mode())
print(df['CUSTOMERNAME'].value_counts())
print(df['CUSTOMERNAME'].describe())
print(df['COUNTRY'].unique())
print(df['COUNTRY'].mode())
print(df['COUNTRY'].value_counts())
print(df['COUNTRY'].describe())
# Out:
# ['Classic Cars' 'Vintage Cars']
# 0    Classic Cars
# Name: PRODUCTLINE, dtype: object
# PRODUCTLINE
# Classic Cars    967
# Vintage Cars    607
# Name: count, dtype: int64
# count             1574
# unique               2
# top       Classic Cars
# freq               967
# Name: PRODUCTLINE, dtype: object
# ['Baane Mini Imports' 'Volvo Model Replicas, Co'
#  'Corrida Auto Replicas, Ltd' 'Technics Stores Inc.'
#  'Dragon Souveniers, Ltd.' 'Classic Legends Inc.'
#  'Australian Gift Network, Co' 'Classic Gift Ideas, Inc'
#  'Saveley & Henriot, Co.' 'Canadian Gift Exchange Network'
#  'West Coast Collectables Co.' 'Cambridge Collectables Co.'
#  'Super Scale Inc.' 'Tokyo Collectables, Ltd' 'Souveniers And Things Co.'
#  'Amica Models & Co.' 'Scandinavian Gift Ideas' 'Auto Assoc. & Cie.'
#  'Mini Gifts Distributors Ltd.' 'Online Diecast Creations Co.'
#  'Mini Wheels Co.' 'Australian Collectors, Co.'
#  'Collectables For Less Inc.' 'Corporate Gift Ideas Co.'
# ...

# %%
# task3
# Perform descriptive analysis of the numerical columns 'PRICE EACH', 'SALES', and 'MSRP' by using the following: Bar chart, Pie chart
import matplotlib.pyplot as plt
df['PRICEEACH'].value_counts().plot(kind='bar')
plt.show()
df['PRICEEACH'].value_counts().plot(kind='pie')    
plt.show()
df['SALES'].value_counts().plot(kind='bar')
plt.show()
df['SALES'].value_counts().plot(kind='pie')
plt.show()
df['MSRP'].value_counts().plot(kind='bar')
plt.show()
df['MSRP'].value_counts().plot(kind='pie')
plt.show()

# %%
# Perform descriptive analysis of the numerical columns 'PRICE EACH', 'SALES', and 'MSRP' by using the following: Measures of central tendency (mean, median)
print(df['PRICEEACH'].mean())
print(df['PRICEEACH'].median())
print(df['SALES'].mean())
print(df['SALES'].median())
print(df['MSRP'].mean())
print(df['MSRP'].median())
# Out:
# 83.79266836086404
# 100.0
# 3699.3433926302414
# 3372.58
# 106.99555273189327
# 102.0

# %%
# Perform descriptive analysis of the numerical columns 'PRICE EACH', 'SALES', and 'MSRP' by using the following:Standard deviation of the column
print(df['PRICEEACH'].std())
print(df['SALES'].std())
print(df['MSRP'].std())
# Out:
# 21.390441196159472
# 2003.3456884795773
# 45.3372820910747

# %%
# Perform descriptive analysis of the numerical columns 'PRICE EACH', 'SALES', and 'MSRP' by using the following:Skewness of the column
print(df['PRICEEACH'].skew())
print(df['SALES'].skew())
print(df['MSRP'].skew())
# Out:
# -1.0447056774338002
# 1.0673366776124145
# 0.3074268660847168

# %%
# task4
# Perform descriptive analysis of the categorical columns 'PRODUCTLINE', 'CUSTOMERNAME', and 'COUNTRY' by using the following:Bar chart, Pie chart,Measures of central tendency (mean, median),Standard deviation of the column,Skewness of the column.
df['PRODUCTLINE'].value_counts().plot(kind='bar')
plt.show()
df['PRODUCTLINE'].value_counts().plot(kind='pie')
plt.show()
df['CUSTOMERNAME'].value_counts().plot(kind='bar')
plt.show()  
df['CUSTOMERNAME'].value_counts().plot(kind='pie')
plt.show()
df['COUNTRY'].value_counts().plot(kind='bar')
plt.show()
df['COUNTRY'].value_counts().plot(kind='pie')
plt.show()
# it is a categorical columns we cannot find mean and median for these columns.
print(df['PRODUCTLINE'].mean())
print(df['PRODUCTLINE'].median())
print(df['CUSTOMERNAME'].mean())
print(df['CUSTOMERNAME'].median())
print(df['COUNTRY'].mean())
print(df['COUNTRY'].median())
print(df['PRODUCTLINE'].std())
print(df['CUSTOMERNAME'].std())
print(df['COUNTRY'].std())
print(df['PRODUCTLINE'].skew())
print(df['CUSTOMERNAME'].skew())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 15
#      13 df['COUNTRY'].value_counts().plot(kind='pie')
#      14 plt.show()
# ---> 15 print(df['PRODUCTLINE'].mean())
#      16 print(df['PRODUCTLINE'].median())
#      17 print(df['CUSTOMERNAME'].mean())
#
# File E:\Git\annaconda\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File E:\Git\annaconda\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# ...

# %%
# task 5
print(df['QUANTITYORDERED'].unique())
print(df['QUANTITYORDERED'].mode())
print(df['QUANTITYORDERED'].value_counts())
print(df['QUANTITYORDERED'].describe())
print(df['PRICEEACH'].unique())
print(df['PRICEEACH'].mode())
print(df['PRICEEACH'].value_counts())
print(df['PRICEEACH'].describe())
print(df['SALES'].unique())
print(df['SALES'].mode())
print(df['SALES'].value_counts())
print(df['SALES'].describe())
print(df['ORDERDATE'].unique())
print(df['ORDERDATE'].mode())
print(df['ORDERDATE'].value_counts())
print(df['ORDERDATE'].describe())
print(df['STATUS'].unique())
print(df['STATUS'].mode())
print(df['STATUS'].value_counts())
print(df['STATUS'].describe())
print(df['PRODUCTLINE'].unique())
print(df['PRODUCTLINE'].mode())
print(df['PRODUCTLINE'].value_counts())
print(df['PRODUCTLINE'].describe())
print(df['MSRP'].unique())
print(df['MSRP'].mode())
print(df['MSRP'].value_counts())
print(df['MSRP'].describe())
print(df['CUSTOMERNAME'].unique())
print(df['CUSTOMERNAME'].mode())
print(df['CUSTOMERNAME'].value_counts())
print(df['CUSTOMERNAME'].describe())
print(df['CITY'].unique())
print(df['CITY'].mode())
print(df['CITY'].value_counts())
print(df['CITY'].describe())
# Perform EDA for various columns such as 'QUANTITYORDERED', 'PRICEEACH', 'SALES','ORDERDATE', 'STATUS', 'PRODUCTLINE','MSRP','CUSTOMERNAME', and 'CITY' by using the following:Bar chart, Pie chart,Measures of central tendency (mean, median),Standard deviation of the column,Skewness of the column.
df['QUANTITYORDERED'].value_counts().plot(kind='bar')
plt.show()
df['QUANTITYORDERED'].value_counts().plot(kind='pie')
plt.show()
df['PRICEEACH'].value_counts().plot(kind='bar')
plt.show()
df['PRICEEACH'].value_counts().plot(kind='pie')
plt.show()
df['SALES'].value_counts().plot(kind='bar')
plt.show()
df['SALES'].value_counts().plot(kind='pie')
plt.show()
df['ORDERDATE'].value_counts().plot(kind='bar')
plt.show()
df['ORDERDATE'].value_counts().plot(kind='pie')
plt.show()
df['STATUS'].value_counts().plot(kind='bar')
plt.show()
df['STATUS'].value_counts().plot(kind='pie')
plt.show()
df['PRODUCTLINE'].value_counts().plot(kind='bar')
plt.show()
df['PRODUCTLINE'].value_counts().plot(kind='pie')
plt.show()
df['MSRP'].value_counts().plot(kind='bar')
plt.show()
df['MSRP'].value_counts().plot(kind='pie')
plt.show()
df['CUSTOMERNAME'].value_counts().plot(kind='bar')
plt.show()
df['CUSTOMERNAME'].value_counts().plot(kind='pie')
plt.show()
df['CITY'].value_counts().plot(kind='bar')
plt.show()
df['CITY'].value_counts().plot(kind='pie')
plt.show()
# Out:
# [26 29 38 37 45 21 34 23 42 47 35 32 48 40 30 41 36 24 50 46 33 49 44 39
#  20 27 25 22 64 19 31 28 43 12 10 55 97 61 51 59 76  6 60 65 58 66 16 15
#  13 18 70 62 56]
# 0    33
# Name: QUANTITYORDERED, dtype: int64
# QUANTITYORDERED
# 33    64
# 20    63
# 34    63
# 27    60
# 46    60
# 26    57
# 24    56
# 25    56
# 45    54
# 31    51
# 49    51
# 22    51
# 36    50
# 39    50
# 37    50
# 44    49
# 48    48
# 29    48
# 41    47
# 21    47
# 40    44
# 47    44
# 23    44
# 32    43
# 43    43
# 28    42
# 42    42
# 30    42
# 38    41
# 50    35
# 35    34
# 55     9
# 61     3
# 15     3
# 60     3
# 51     3
# 76     3
# 10     2
# 59     2
# 64     2
# 6      2
# 66     2
# 97     1
# 12     1
# 65     1
# 58     1
# 16     1
# 19     1
# 13     1
# 18     1
# 70     1
# 62     1
# 56     1
# Name: count, dtype: int64
# count    1574.000000
# mean       34.981576
# std         9.935919
# min         6.000000
# 25%        27.000000
# 50%        34.000000
# ...
