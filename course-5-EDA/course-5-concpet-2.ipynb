# %%
import matplotlib.pyplot as plt
import matplotlib as mat
import pandas as pd
import numpy as np
import seaborn as sns
from tabulate import tabulate

# %%
df=pd.read_csv('DS1_C5_S2_BankChurn_Data_Concept.csv')
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
df.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# ...

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Trans_Amt', 'Total_Trans_Ct',
#        'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                     0
# Attrition_Flag                0
# Customer_Age                  0
# Gender                       93
# Dependent_count               0
# Education_Level               0
# Marital_Status                0
# Income_Category               0
# Card_Category               132
# Months_on_book                0
# Total_Relationship_Count      0
# Months_Inactive_12_mon        0
# Contacts_Count_12_mon         0
# Credit_Limit                 60
# Total_Revolving_Bal           0
# Avg_Open_To_Buy               0
# Total_Trans_Amt               0
# Total_Trans_Ct                0
# Avg_Utilization_Ratio         0
# dtype: int64

# %%
cat_col=df.select_dtypes(include='object')
cat_col
# Out:
#           Attrition_Flag Gender Education_Level Marital_Status  \
# 0      Existing Customer      M     High School        Married
# 1      Existing Customer      F        Graduate         Single
# 2      Existing Customer      M        Graduate        Married
# 3      Existing Customer      F     High School        Unknown
# 4      Existing Customer      M      Uneducated        Married
# ...                  ...    ...             ...            ...
# 10122  Existing Customer      M        Graduate         Single
# 10123  Attrited Customer      M         Unknown       Divorced
# 10124  Attrited Customer      F     High School        Married
# 10125  Attrited Customer      M        Graduate        Unknown
# 10126  Attrited Customer      F        Graduate        Married
#
#       Income_Category Card_Category
# 0         $60K - $80K          Blue
# 1      Less than $40K          Blue
# 2        $80K - $120K          Blue
# 3      Less than $40K          Blue
# ...

# %%
num_col=df.select_dtypes(exclude='object')
num_col
# Out:
#        CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# 0      768805383            45                3              39
# 1      818770008            49                5              44
# 2      713982108            51                3              36
# 3      769911858            40                4              34
# 4      709106358            40                3              21
# ...          ...           ...              ...             ...
# 10122  772366833            50                2              40
# 10123  710638233            41                2              25
# 10124  716506083            44                1              36
# 10125  717406983            30                2              36
# 10126  714337233            43                2              25
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                             5                       1
# 1                             6                       1
# ...

# %%
n_list=list(num_col.columns)
n_list
# Out:
# ['CLIENTNUM',
#  'Customer_Age',
#  'Dependent_count',
#  'Months_on_book',
#  'Total_Relationship_Count',
#  'Months_Inactive_12_mon',
#  'Contacts_Count_12_mon',
#  'Credit_Limit',
#  'Total_Revolving_Bal',
#  'Avg_Open_To_Buy',
#  'Total_Trans_Amt',
#  'Total_Trans_Ct',
#  'Avg_Utilization_Ratio']

# %%
c_list=list(cat_col.columns)
c_list
# Out:
# ['Attrition_Flag',
#  'Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category']

# %%
table=[n_list,c_list]
print(tabulate({'Categorical':c_list,'Numerical':n_list},headers=['Categorical','Numerical']))
# Out:
# Categorical      Numerical
# ---------------  ------------------------
# Attrition_Flag   CLIENTNUM
# Gender           Customer_Age
# Education_Level  Dependent_count
# Marital_Status   Months_on_book
# Income_Category  Total_Relationship_Count
# Card_Category    Months_Inactive_12_mon
#                  Contacts_Count_12_mon
#                  Credit_Limit
#                  Total_Revolving_Bal
#                  Avg_Open_To_Buy
#                  Total_Trans_Amt
#                  Total_Trans_Ct
#                  Avg_Utilization_Ratio

# %%
# show the relationship gender and Attrition_Flag
figure,ax=plt.subplots(1,figsize=(15,7))
sns.countplot(x='Gender',hue='Attrition_Flag',data=df)
plt.show()

# %%
df_F=df[(df['Gender']=='F')]
df_F
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 1      818770008  Existing Customer            49      F                5
# 3      769911858  Existing Customer            40      F                4
# 14     712396908  Existing Customer            57      F                2
# 19     709327383  Existing Customer            45      F                2
# 21     708508758  Attrited Customer            62      F                0
# ...          ...                ...           ...    ...              ...
# 10106  717494358  Existing Customer            58      F                0
# 10119  716893683  Attrited Customer            55      F                3
# 10121  713899383  Existing Customer            56      F                1
# 10124  716506083  Attrited Customer            44      F                1
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
figure,ax=plt.subplots(1,figsize=(50,20))
sns.countplot(x='Customer_Age',hue='Attrition_Flag',data=df_F)
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(x=df_F['Customer_Age'],hue=df_F['Attrition_Flag'],ax=ax[0])
sns.boxplot(y=df_F['Customer_Age'],hue=df_F['Attrition_Flag'],ax=ax[1])
# Out:
# <Axes: ylabel='Customer_Age'>

# %%
# most of the bank female existing customer are from 40 to 50 age group.

# %%
# find the relationship of attrtion flag with the creditlimit
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                     0
# Attrition_Flag                0
# Customer_Age                  0
# Gender                       93
# Dependent_count               0
# Education_Level               0
# Marital_Status                0
# Income_Category               0
# Card_Category               132
# Months_on_book                0
# Total_Relationship_Count      0
# Months_Inactive_12_mon        0
# Contacts_Count_12_mon         0
# Credit_Limit                 60
# Total_Revolving_Bal           0
# Avg_Open_To_Buy               0
# Total_Trans_Amt               0
# Total_Trans_Ct                0
# Avg_Utilization_Ratio         0
# dtype: int64

# %%
# univariate
def info_of_cat(col):
    print(f"unique values in {col} are:{df[col].nunique()}") #unique willl return the unique value of each column
    print(f"mean values in {col} is:{df[col].mean()}") #it will return mode pf a column
    print(f"number of missing value in {col} are :{df[col].isnull().sum()}") #it will return the count of missing values

# %%
info_of_cat('Credit_Limit')
# Out:
# unique values in Credit_Limit are:6181
# Mode values in Credit_Limit is:34516.0
# number of missing value in Credit_Limit are :60

# %%
df['Credit_Limit'].mean()
# Out:
# 8703.180550312904

# %%
df['Credit_Limit']=df['Credit_Limit'].fillna(8703.180550312904)

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                     0
# Attrition_Flag                0
# Customer_Age                  0
# Gender                       93
# Dependent_count               0
# Education_Level               0
# Marital_Status                0
# Income_Category               0
# Card_Category               132
# Months_on_book                0
# Total_Relationship_Count      0
# Months_Inactive_12_mon        0
# Contacts_Count_12_mon         0
# Credit_Limit                  0
# Total_Revolving_Bal           0
# Avg_Open_To_Buy               0
# Total_Trans_Amt               0
# Total_Trans_Ct                0
# Avg_Utilization_Ratio         0
# dtype: int64

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(x=df['Credit_Limit'],hue=df['Attrition_Flag'],ax=ax[0],data=df,kde=True)
sns.boxplot(y=df['Credit_Limit'],hue=df['Attrition_Flag'],ax=ax[1],data=df)
# Out:
# <Axes: ylabel='Credit_Limit'>

# %%
# find the relationship with of attrition flg with card category and check which card category of the majority are chruning
# further anayse the most chruned cutomer for the particular category
# anayse the churned customer who hold the blue card with respect to thier income category

# how is the income category and credit category affecting of transacion amount of blue card holder who still with the bank

# %%
sns.boxplot(x='Attrition_Flag',y='Credit_Limit',hue='Income_Category',data=df)
# Out:
# <Axes: xlabel='Attrition_Flag', ylabel='Credit_Limit'>

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df1
#
# NameError: name 'df1' is not defined
