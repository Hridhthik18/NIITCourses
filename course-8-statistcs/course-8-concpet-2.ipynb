# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
emp_df=pd.read_csv('DS1_C8_S2_Employee_Data_Concept.csv')
emp_df
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 0             1010    Male         IT             27000           1   22
# 1             1011  Female         IT             48000           4   27
# 2             1012    Male      Sales             75000          10   31
# 3             1013    Male      Sales             71000           4   29
# 4             1014  Female    Finance             45000           4   27
# ..             ...     ...        ...               ...         ...  ...
# 95            1104    Male    Finance             81250           8   46
# 96            1105    Male      Sales             74580           7   41
# 97            1106  Female         HR             68200           6   36
# 98            1107    Male         IT             54520           7   38
# 99            1108    Male      Sales             74000           7   37
#
# [100 rows x 6 columns]

# %%
df_10=emp_df.head(10)
df_10
# Out:
#    Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 0            1010    Male         IT             27000           1   22
# 1            1011  Female         IT             48000           4   27
# 2            1012    Male      Sales             75000          10   31
# 3            1013    Male      Sales             71000           4   29
# 4            1014  Female    Finance             45000           4   27
# 5            1015    Male    Finance             40000           0   26
# 6            1016  Female         HR             42000           2   27
# 7            1017    Male         IT             28000           1   23
# 8            1018  Female         IT             48000           4   27
# 9            1019    Male      Sales             75000           4   32

# %%
import statistics as st

# %%
# calculating the mean
mean_p=st.mean(emp_df['Annual_Salary($)'])
print('population mean:',mean_p)
# Out:
# population mean: 62392.6

# %%
mean_s=st.mean(df_10['Annual_Salary($)'])
print('sample mean:',mean_s)
# Out:
# sample mean: 49900

# %%
# simple random sampling without replacement
emp_df.sample(n=20,random_state=1)
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 80            1089  Female         HR             86000           9   40
# 84            1093    Male         HR             54260           7   35
# 33            1042    Male      Sales             32000           9   24
# 81            1090    Male    Finance             85000           9   45
# 93            1102  Female      Sales             55800           6   33
# 17            1027  Female         HR             28000           1   22
# 36            1045  Female         IT             63000           4   28
# 82            1091  Female         IT             59420           4   30
# 69            1078    Male    Finance             92000          10   45
# 65            1074  Female         HR             82500          10   43
# 92            1101  Female    Finance             55840           1   25
# 39            1048    Male    Finance             55000          10   26
# ...

# %%
# simple random sampling with replacement
emp_df.sample(n=20,replace=True,random_state=1)
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 37            1046  Female         HR             61000           4   28
# 12            1022    Male         IT             29000           0   22
# 72            1081    Male    Finance             75000           9   31
# 9             1019    Male      Sales             75000           4   32
# 75            1084    Male         IT             86000           4   28
# 5             1015    Male    Finance             40000           0   26
# 79            1088    Male      Sales             84210           9   39
# 64            1073    Male         IT            110000          10   50
# 16            1026    Male      Sales             64000           4   28
# 1             1011  Female         IT             48000           4   27
# 76            1085  Female    Finance             62000           4   24
# 71            1080  Female    Finance             74000           8   32
# ...

# %%
# 20% of 70(population)=14,either n=14 or frac=0.2
emp_df.sample(frac=0.2,random_state=1)
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 80            1089  Female         HR             86000           9   40
# 84            1093    Male         HR             54260           7   35
# 33            1042    Male      Sales             32000           9   24
# 81            1090    Male    Finance             85000           9   45
# 93            1102  Female      Sales             55800           6   33
# 17            1027  Female         HR             28000           1   22
# 36            1045  Female         IT             63000           4   28
# 82            1091  Female         IT             59420           4   30
# 69            1078    Male    Finance             92000          10   45
# 65            1074  Female         HR             82500          10   43
# 92            1101  Female    Finance             55840           1   25
# 39            1048    Male    Finance             55000          10   26
# ...

# %%
emp_df.sample(n=14,random_state=1)
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 80            1089  Female         HR             86000           9   40
# 84            1093    Male         HR             54260           7   35
# 33            1042    Male      Sales             32000           9   24
# 81            1090    Male    Finance             85000           9   45
# 93            1102  Female      Sales             55800           6   33
# 17            1027  Female         HR             28000           1   22
# 36            1045  Female         IT             63000           4   28
# 82            1091  Female         IT             59420           4   30
# 69            1078    Male    Finance             92000          10   45
# 65            1074  Female         HR             82500          10   43
# 92            1101  Female    Finance             55840           1   25
# 39            1048    Male    Finance             55000          10   26
# ...

# %%
# systematic
systematic_sampling=emp_df[::5]
systematic_sampling
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 0             1010    Male         IT             27000           1   22
# 5             1015    Male    Finance             40000           0   26
# 10            1020    Male      Sales             64000           4   28
# 15            1025    Male         IT             68000           4   33
# 20            1030    Male      Sales             94000           4   37
# 25            1035    Male         IT             36000           1   26
# 30            1040    Male         HR             38000           1   26
# 35            1044  Female      Sales             28500           1   23
# 40            1049    Male    Finance             65000           9   32
# 45            1054    Male    Finance             63000           4   36
# 50            1059    Male      Sales             60000           9   30
# 55            1064    Male         HR             65000           9   44
# ...

# %%
# stratified samplings
grouped_emp_df=emp_df.groupby(["Department"])
departments=emp_df.Department.unique()
strat_sample_df=pd.DataFrame()

for d in departments:
    d_data=grouped_emp_df.get_group(d)
    sample_data=d_data.sample(n=5,random_state=1)
    strat_sample_df=strat_sample_df.append(sample_data,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20616\4117573496.py in ?()
#       5
#       6 for d in departments:
#       7     d_data=grouped_emp_df.get_group(d)
#       8     sample_data=d_data.sample(n=5,random_state=1)
# ----> 9     strat_sample_df=strat_sample_df.append(sample_data,ignore_index=True)
#
# ~\hridhthik-python\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# stratified samplings
grouped_emp_df=emp_df.groupby(["Department"])
departments=emp_df.Department.unique()
strat_sample_df=[]

for d in departments:
    d_data=grouped_emp_df.get_group(d)
    sample_data=d_data.sample(n=5,random_state=1)
    strat_sample_df.append(sample_data)

# %%
strat_sample_df=pd.concat(strat_sample_df,ignore_index=True)
strat_sample_df

# %%
grouped_emp_df=emp_df.groupby(["Department"])

# %%
for d in grouped_emp_df:
    print(d)
# Out:
# (('Finance',),     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 4             1014  Female    Finance             45000           4   27
# 5             1015    Male    Finance             40000           0   26
# 13            1023    Male    Finance             48000           2   27
# 22            1032  Female    Finance             30000           4   24
# 23            1033    Male    Finance             48000           4   27
# 31            1040    Male    Finance             68000           3   32
# 39            1048    Male    Finance             55000          10   26
# 40            1049    Male    Finance             65000           9   32
# 45            1054    Male    Finance             63000           4   36
# 51            1060    Male    Finance             62700           4   41
# 53            1062    Male    Finance             78000           9   40
# 61            1070    Male    Finance             78000           7   37
# ...

# %%
# cluster samplings

grouped_emp_df=emp_df.groupby(["Department"])
departs=['HR','IT']
c_sample_df=[]

for dep in departs:
    dep_data=grouped_emp_df.get_group(dep)
    sample_data=dep_data.sample(n=5,random_state=1)
    c_sample_df.append(sample_data)

# %%
c_sample_df
# Out:
# [    Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
#  18            1028    Male         HR             36000           0   25
#  77            1086    Male         HR             75680           4   29
#  30            1040    Male         HR             38000           1   26
#  49            1058  Female         HR             58500           2   34
#  17            1027  Female         HR             28000           1   22,
#      Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
#  89            1098    Male         IT             54860           3   28
#  8             1018  Female         IT             48000           4   27
#  62            1071    Male         IT             95400           7   39
#  75            1084    Male         IT             86000           4   28
#  73            1082    Male         IT             79540           4   39]

# %%
c_sample_df=pd.concat(c_sample_df,ignore_index=True)
c_sample_df
# Out:
#    Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 0            1028    Male         HR             36000           0   25
# 1            1086    Male         HR             75680           4   29
# 2            1040    Male         HR             38000           1   26
# 3            1058  Female         HR             58500           2   34
# 4            1027  Female         HR             28000           1   22
# 5            1098    Male         IT             54860           3   28
# 6            1018  Female         IT             48000           4   27
# 7            1071    Male         IT             95400           7   39
# 8            1084    Male         IT             86000           4   28
# 9            1082    Male         IT             79540           4   39

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salary_df=emp_df[('Annual_Salary($)')]
sns.histplot(salary_df,bins=5)
plt.xlabel('Annual_Salary')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
sal_10=salary_df.sample(n=10,replace=True,random_state=1)
sal_10
# Out:
# 37     61000
# 12     29000
# 72     75000
# 9      75000
# 75     86000
# 5      40000
# 79     84210
# 64    110000
# 16     64000
# 1      48000
# Name: Annual_Salary($), dtype: int64

# %%
# 10 size
sns.histplot(sal_10,bins=5)
plt.xlabel('Annual_Salary')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
sal_20=salary_df.sample(n=20,replace=True,random_state=1)
sal_20
# Out:
# 37     61000
# 12     29000
# 72     75000
# 9      75000
# 75     86000
# 5      40000
# 79     84210
# 64    110000
# 16     64000
# 1      48000
# 76     62000
# 71     74000
# 6      42000
# 25     36000
# 50     60000
# 20     94000
# 18     36000
# 84     54260
# 11     45000
# 28     56000
# Name: Annual_Salary($), dtype: int64

# %%
sns.histplot(sal_20,bins=5)
plt.xlabel('Annual_Salary')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
sal_30=salary_df.sample(n=30,replace=True,random_state=1)
sal_30
# Out:
# 37     61000
# 12     29000
# 72     75000
# 9      75000
# 75     86000
# 5      40000
# 79     84210
# 64    110000
# 16     64000
# 1      48000
# 76     62000
# 71     74000
# 6      42000
# 25     36000
# 50     60000
# 20     94000
# 18     36000
# 84     54260
# 11     45000
# 28     56000
# 29     65000
# 14     95000
# 50     60000
# 68     66500
# 87     74150
# 87     74150
# 94     95420
# 96     74580
# 86     74580
# 13     48000
# Name: Annual_Salary($), dtype: int64

# %%
sns.histplot(sal_30,bins=5)
plt.xlabel('Annual_Salary')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
sal_40=salary_df.sample(n=40,replace=True,random_state=1)
sal_40
# Out:
# 37     61000
# 12     29000
# 72     75000
# 9      75000
# 75     86000
# 5      40000
# 79     84210
# 64    110000
# 16     64000
# 1      48000
# 76     62000
# 71     74000
# 6      42000
# 25     36000
# 50     60000
# 20     94000
# 18     36000
# 84     54260
# 11     45000
# 28     56000
# 29     65000
# 14     95000
# 50     60000
# 68     66500
# 87     74150
# 87     74150
# 94     95420
# 96     74580
# 86     74580
# 13     48000
# 9      75000
# 7      28000
# 63     60000
# 61     78000
# 22     30000
# 57     68000
# 1      48000
# 0      27000
# 60     62500
# 81     85000
# Name: Annual_Salary($), dtype: int64

# %%
sns.histplot(sal_40,bins=5)
plt.xlabel('Annual_Salary')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
sal_50=salary_df.sample(n=50,replace=True,random_state=1)
sal_50
# Out:
# 37     61000
# 12     29000
# 72     75000
# 9      75000
# 75     86000
# 5      40000
# 79     84210
# 64    110000
# 16     64000
# 1      48000
# 76     62000
# 71     74000
# 6      42000
# 25     36000
# 50     60000
# 20     94000
# 18     36000
# 84     54260
# 11     45000
# 28     56000
# 29     65000
# 14     95000
# 50     60000
# 68     66500
# 87     74150
# 87     74150
# 94     95420
# 96     74580
# 86     74580
# 13     48000
# 9      75000
# 7      28000
# 63     60000
# 61     78000
# 22     30000
# 57     68000
# 1      48000
# 0      27000
# 60     62500
# 81     85000
# 8      48000
# 88     54820
# 13     48000
# 47     69000
# 72     75000
# 30     38000
# 71     74000
# 3      71000
# 70     78000
# 21     42000
# Name: Annual_Salary($), dtype: int64

# %%
sns.histplot(sal_50,bins=5)
plt.xlabel('Annual_Salary')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
sal_60=salary_df.sample(n=60,replace=True,random_state=1)
sal_60
# Out:
# 37     61000
# 12     29000
# 72     75000
# 9      75000
# 75     86000
# 5      40000
# 79     84210
# 64    110000
# 16     64000
# 1      48000
# 76     62000
# 71     74000
# 6      42000
# 25     36000
# 50     60000
# 20     94000
# 18     36000
# 84     54260
# 11     45000
# 28     56000
# 29     65000
# 14     95000
# 50     60000
# 68     66500
# 87     74150
# 87     74150
# 94     95420
# 96     74580
# 86     74580
# 13     48000
# 9      75000
# 7      28000
# 63     60000
# 61     78000
# 22     30000
# 57     68000
# 1      48000
# 0      27000
# 60     62500
# 81     85000
# 8      48000
# 88     54820
# 13     48000
# 47     69000
# 72     75000
# 30     38000
# 71     74000
# 3      71000
# 70     78000
# 21     42000
# 49     58500
# 57     68000
# 3      71000
# 68     66500
# 24     62000
# 43     61000
# 76     62000
# 26     48000
# 52     67000
# 80     86000
# Name: Annual_Salary($), dtype: int64

# %%
sns.histplot(sal_60,bins=5)
plt.xlabel('Annual_Salary')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
num = [5,10,20,30,40,50,60,70]
data_s = []
sample_df = pd.DataFrame()

fig,ax = plt.subplots(2,4, figsize = (14,10))
for i in num:
    sample_df = emp_df.sample(n=i, replace = True, random_state=1)
    data_s.append(sample_df["Annual_Salary($)"].tolist())

k = 0
for i in range(0,2):
    for j in range(0,4):
        ax[i,j].hist(data_s[k],5,density = True)
        ax[i,j].set_title(label='Sample size=' +str(len(data_s[k])))
        k = k + 1
plt.show()

# %%
sal_10
# Out:
# 37     61000
# 12     29000
# 72     75000
# 9      75000
# 75     86000
# 5      40000
# 79     84210
# 64    110000
# 16     64000
# 1      48000
# Name: Annual_Salary($), dtype: int64

# %%
import statistics as st
import scipy.stats as sts

# %%
data_d=emp_df['Annual_Salary($)'].tolist()

# %%
p_mean=st.mean(data_d)
p_median=st.median(data_d)
p_std=st.stdev(data_d)

# %%
skewness=sts.skew(data_d,bias=False)

# %%
kurtosis=sts.kurtosis(data_d,bias=False)

# %%
print('mean',p_mean)
print('median',p_median)
print('standard_deviation',p_std)
print('skewness',skewness)
print('kurtosis',kurtosis)
# Out:
# mean 62392.6
# median 62600.0
# standard_deviation 17836.06892753778
# skewness -0.059690326690678586
# kurtosis -0.2631784946504583

# %%
sal_mean=st.mean(sal_40)
sal_median=st.median(sal_40)
sal_std=st.stdev(sal_40)
skewness_sal=sts.skew(sal_40,bias=False)
kurtosis_sal=sts.kurtosis(sal_40,bias=False)


print('mean',sal_mean)
print('median',sal_median)
print('standard_deviation',sal_std)
print('skewness',skewness_sal)
print('kurtosis',kurtosis_sal)
# Out:
# mean 63008.75
# median 63250.0
# standard_deviation 20503.684995566917
# skewness 0.01786266831922765
# kurtosis -0.4746525254913867

# %% [markdown]
# # Noted that mean is nearer arounded to the Median ~ Mean for both population kurtosis and skewness is 0
# # which implies that population data and sample data which sample size 40 both are normally Distrubuted also note in our example population mean 62932.6 and sample mean 63250.0 which indicates sample mean is near around to the Population Mean.
# # All of the above are nearly Equal
# # so this is proving Central Limit Theorem

# %%
sample_df1=pd.DataFrame()

for i in range(0,20):
    sample_df1['sample_'+str(i)]=emp_df['Annual_Salary($)'].sample(n=40,replace=True).reset_index(drop=True)

# %%
sample_df1
# Out:
#     sample_0  sample_1  sample_2  sample_3  sample_4  sample_5  sample_6  \
# 0      55840     36000     79540     62200     55000     42000     61000
# 1      68000     78540     64000     54860     28000     78540     58500
# 2      78000     65000     62000     67000     78000     55840     54860
# 3      74000     28500     62700     55800     95400     59420     36000
# 4      74580     68000     38000     75000     74210     95420     65000
# 5      61000     64000     62000     42000     55000     74580     36000
# 6      61000     90000     95420     54860     42000     60000     68000
# 7      74580     60000     82500     29000     85000     45000     75000
# 8      95400     71000     48000     75000     54520     62000     68000
# 9      48000     42000     48000     75680     60000     76000     42000
# 10     48000     75000     85000     58000     48000    110000     71000
# 11     58500     54820     74000     65000     45000     63500     63000
# ...

# %%
sample_name =sample_df1.columns

fig,ax = plt.subplots(5,4, figsize = (15,8))
fig.tight_layout()

  
k = 0
for i in range(0,5):
    for j in range(0,4):
        ax[i,j].hist(sample_df1[sample_name[k]],5,density = True)
        ax[i,j].set_title(label='Sample size=' +sample_name[k])
        k = k + 1
plt.show()

# %%
sample_name =sample_df1.columns

# %%
sample_name
# Out:
# Index(['sample_0', 'sample_1', 'sample_2', 'sample_3', 'sample_4', 'sample_5',
#        'sample_6', 'sample_7', 'sample_8', 'sample_9', 'sample_10',
#        'sample_11', 'sample_12', 'sample_13', 'sample_14', 'sample_15',
#        'sample_16', 'sample_17', 'sample_18', 'sample_19'],
#       dtype='object')

# %%
# demo 6-2
sample_mean=[]
sample_name =sample_df1.columns
for i in sample_name:
    sample_mean.append(sample_df1[i].mean())

samples_mean=pd.DataFrame()
samples_mean.insert(0,'sample_name',sample_name)
samples_mean.insert(1,'sample_mean',sample_mean)

# %%
samples_mean.head()
# Out:
#   sample_name  sample_mean
# 0    sample_0     62554.00
# 1    sample_1     61086.75
# 2    sample_2     63241.75
# 3    sample_3     62628.25
# 4    sample_4     58008.50

# %%
samples_mean_std=st.stdev(samples_mean['sample_mean'])
print('samples_mean_std:',samples_mean_std)
# Out:
# samples_mean_std: 2697.45159031119

# %%
# calculate sample std from population paramater

import math as m

# %%
calulated_sd=p_std/m.sqrt(40)
calulated_sd
# Out:
# 2820.130115738805

# %%
# we found calculated samples mean std is near around sample std calculated using population std.
# as sample size increases the std of the samples becomes smaller and samller because the population std 
# is being divided larger and lrager values of sqrt(n). 

# 1 the sample distribution curve is tending to be normal distribution curve irrespective the type of population distribution
# when the sampe size is greater than 30

#2 sample mean is near around population mean

#3 the std of samples mean is the std of population is the divided by the square root of sample size
# above property theorem is clt of any sampling distribution.
# using the clt we can justify the sample data to properly represent of population data so this samples represent properly population and furtger we can proceed for analysis for data

# %%
# probabilty distribution curve of population and sample
from scipy.stats import norm
import numpy as np

# %%
lower_p=p_mean-3*p_std
upper_p=p_mean+3*p_std
norm_p=np.arange(lower_p,upper_p)
plt.plot(norm_p,norm.pdf(norm_p,p_mean,p_std))

# %%
norm.pdf(norm_p,p_mean,p_std)
# Out:
# array([2.48476748e-07, 2.48518545e-07, 2.48560348e-07, ...,
#        2.48577638e-07, 2.48535832e-07, 2.48494033e-07])

# %%
lower_s=sal_mean-4*sal_std
upper_s=sal_mean+4*sal_std
norm_s=np.arange(lower_s,upper_s)
plt.plot(norm_s,norm.pdf(norm_s,sal_mean,sal_std))
